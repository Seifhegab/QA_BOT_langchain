# %% [markdown]
# # **QA BOT USING WatsonX AI**

# %%
# !sudo apt-get update -y
# !sudo apt-get install python3.11
# !python3.11 -m ensurepip
# !python3.11 -m pip install --upgrade pip
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3.11 is already the newest version (3.11.15-1+jammy1).
# 0 upgraded, 0 newly installed, 0 to remove and 30 not upgraded.
# /usr/bin/python3.11: No module named ensurepip
# /usr/bin/python3.11: No module named pip

# %% [markdown]
# # Import necessary libraries
# To ensure seamless execution of your scripts, and considering that certain functions within these scripts rely on external libraries, it's essential to install some prerequisite libraries before you begin. For this project, the key libraries you'll need are Gradio for creating user-friendly web interfaces and IBM watsonx AI for leveraging advanced LLM models from IBM watsonx's API.
#
# gradio allows you to build interactive web applications quickly, making your AI models accessible to users with ease.
# ibm-watsonx-ai for using LLMs from IBM's watsonx.ai.
# langchain, langchain-ibm, langchain-community for using relevant features from Langchain.
# chromadb for using the chroma database as a vector database.
# pypdf is required for loading PDF documents.
# Here's how to install these packages (from your terminal):

# %%
# !python3.11 -m pip install \
gradio==4.44.0 \
ibm-watsonx-ai==1.1.2  \
langchain==0.2.11 \
langchain-community==0.2.10 \
langchain-ibm==0.1.11 \
chromadb==0.4.24 \
pypdf==4.3.1 \
pydantic==2.9.1
! pip install -U ibm-watsonx-ai
! pip install -U langchain_ibm
! pip install -U langchain-text-splitters
! pip install -U langchain-community
! pip install -U langchain-classic
# Out:
# /usr/bin/python3.11: No module named pip
# Requirement already satisfied: ibm-watsonx-ai in /usr/local/lib/python3.13/dist-packages (1.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from ibm-watsonx-ai) (2.32.4)
# Requirement already satisfied: httpx<0.29,>=0.27 in /usr/local/lib/python3.13/dist-packages (from ibm-watsonx-ai) (0.28.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.13/dist-packages (from ibm-watsonx-ai) (2.5.0)
# Requirement already satisfied: pandas<2.4.0,>=0.24.2 in /usr/local/lib/python3.13/dist-packages (from ibm-watsonx-ai) (2.2.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from ibm-watsonx-ai) (2026.7.22)
# Requirement already satisfied: lomond in /usr/local/lib/python3.13/dist-packages (from ibm-watsonx-ai) (0.3.3)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.13/dist-packages (from ibm-watsonx-ai) (0.9.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from ibm-watsonx-ai) (26.3)
# Requirement already satisfied: ibm-cos-sdk<2.15.0,>=2.12.0 in /usr/local/lib/python3.13/dist-packages (from ibm-watsonx-ai) (2.14.3)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.13/dist-packages (from ibm-watsonx-ai) (6.2.6)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<0.29,>=0.27->ibm-watsonx-ai) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<0.29,>=0.27->ibm-watsonx-ai) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<0.29,>=0.27->ibm-watsonx-ai) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<0.29,>=0.27->ibm-watsonx-ai) (0.16.0)
# Requirement already satisfied: ibm-cos-sdk-core==2.14.3 in /usr/local/lib/python3.13/dist-packages (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai) (2.14.3)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.14.3 in /usr/local/lib/python3.13/dist-packages (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai) (2.14.3)
# Requirement already satisfied: jmespath<=1.0.1,>=0.10.0 in /usr/local/lib/python3.13/dist-packages (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0 in /usr/local/lib/python3.13/dist-packages (from ibm-cos-sdk-core==2.14.3->ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.13/dist-packages (from pandas<2.4.0,>=0.24.2->ibm-watsonx-ai) (2.1.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas<2.4.0,>=0.24.2->ibm-watsonx-ai) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas<2.4.0,>=0.24.2->ibm-watsonx-ai) (2026.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->ibm-watsonx-ai) (3.4.9)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.13/dist-packages (from lomond->ibm-watsonx-ai) (1.17.0)
# Requirement already satisfied: langchain_ibm in /usr/local/lib/python3.13/dist-packages (1.1.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.22 in /usr/local/lib/python3.13/dist-packages (from langchain_ibm) (1.6.0)
# Requirement already satisfied: ibm-watsonx-ai<2.0.0,>=1.3.37 in /usr/local/lib/python3.13/dist-packages (from langchain_ibm) (1.7.1)
# Requirement already satisfied: json-repair<1.0.0,>=0.30.0 in /usr/local/lib/python3.13/dist-packages (from langchain_ibm) (0.63.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (2.32.4)
# Requirement already satisfied: httpx<0.29,>=0.27 in /usr/local/lib/python3.13/dist-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (0.28.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.13/dist-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (2.5.0)
# Requirement already satisfied: pandas<2.4.0,>=0.24.2 in /usr/local/lib/python3.13/dist-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (2.2.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (2026.7.22)
# Requirement already satisfied: lomond in /usr/local/lib/python3.13/dist-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (0.3.3)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.13/dist-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (0.9.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (26.3)
# Requirement already satisfied: ibm-cos-sdk<2.15.0,>=2.12.0 in /usr/local/lib/python3.13/dist-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (2.14.3)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.13/dist-packages (from ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (6.2.6)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.22->langchain_ibm) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.22->langchain_ibm) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.22->langchain_ibm) (0.11.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.22->langchain_ibm) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.22->langchain_ibm) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.22->langchain_ibm) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.22->langchain_ibm) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.22->langchain_ibm) (0.17.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<0.29,>=0.27->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<0.29,>=0.27->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<0.29,>=0.27->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<0.29,>=0.27->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (0.16.0)
# Requirement already satisfied: ibm-cos-sdk-core==2.14.3 in /usr/local/lib/python3.13/dist-packages (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (2.14.3)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.14.3 in /usr/local/lib/python3.13/dist-packages (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (2.14.3)
# Requirement already satisfied: jmespath<=1.0.1,>=0.10.0 in /usr/local/lib/python3.13/dist-packages (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0 in /usr/local/lib/python3.13/dist-packages (from ibm-cos-sdk-core==2.14.3->ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (2.9.0.post0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.22->langchain_ibm) (3.1.1)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.22->langchain_ibm) (1.9.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.22->langchain_ibm) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.22->langchain_ibm) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.22->langchain_ibm) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.22->langchain_ibm) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.22->langchain_ibm) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.22->langchain_ibm) (0.25.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.13/dist-packages (from pandas<2.4.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (2.1.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas<2.4.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas<2.4.0,>=0.24.2->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (2026.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.22->langchain_ibm) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.22->langchain_ibm) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.22->langchain_ibm) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (3.4.9)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.13/dist-packages (from lomond->ibm-watsonx-ai<2.0.0,>=1.3.37->langchain_ibm) (1.17.0)
# Requirement already satisfied: langchain-text-splitters in /usr/local/lib/python3.13/dist-packages (1.1.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in /usr/local/lib/python3.13/dist-packages (from langchain-text-splitters) (1.6.0)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.11.1)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (26.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.17.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.1.1)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.9.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.32.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.5.0)
# Collecting langchain-community
#   Downloading langchain_community-0.4.2-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (3.14.3)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting langchain-classic<2.0.0,>=1.0.7 (from langchain-community)
#   Downloading langchain_classic-1.0.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (1.6.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (0.11.1)
# Requirement already satisfied: numpy>=2.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (2.1.3)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Downloading pydantic_settings-2.15.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (6.0.3)
# Collecting requests<3.0.0,>=2.32.5 (from langchain-community)
#   Downloading requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (2.0.52)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.5)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in /usr/local/lib/python3.13/dist-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.13/dist-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.13.4)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.0.18)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (26.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.17.0)
# Requirement already satisfied: anyio>=3.5.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.9.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.13/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.3)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.13/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.7.22)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.13/dist-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (3.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.46.4)
# Downloading langchain_community-0.4.2-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 32.5 MB/s eta 0:00:00
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.8-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 41.3 MB/s eta 0:00:00
# Downloading pydantic_settings-2.15.0-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 3.5 MB/s eta 0:00:00
# Downloading requests-2.34.2-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 6.1 MB/s eta 0:00:00
# Installing collected packages: requests, httpx-sse, pydantic-settings, langchain-classic, langchain-community
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# Successfully installed httpx-sse-0.4.3 langchain-classic-1.0.8 langchain-community-0.4.2 pydantic-settings-2.15.0 requests-2.34.2

# %% [markdown]
# # IMPORT LIBRARIES
#
# Inside qabot.py, import the following from gradio, ibm_watsonx.ai, langchain_ibm, langchain, and langchain_community. The imported classes are necessary for initializing models with the correct credentials, splitting text, initializing a vector store, loading PDFs, generating a question-answer retriever, and using Gradio.

# %%
from ibm_watsonx_ai.foundation_models import ModelInference
from ibm_watsonx_ai.metanames import GenTextParamsMetaNames as GenParams
from ibm_watsonx_ai.metanames import EmbedTextParamsMetaNames
from ibm_watsonx_ai import Credentials
from langchain_ibm import WatsonxLLM, WatsonxEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import Chroma
from langchain_community.document_loaders import PyPDFLoader
from langchain_classic.chains import RetrievalQA


# You can use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

# %%
import gradio as gr

def chatbot_response(user_input):
    # Replace this with your WatsonxLLM model call or chatbot function
    return "This is a placeholder response for: " + user_input

iface = gr.Interface(
    fn=chatbot_response,  # The function that generates a response
    inputs=gr.Textbox(lines=2, placeholder="Ask me anything..."),
    outputs=gr.Textbox()
)

iface.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://e79b794d41302dfd85.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://e79b794d41302dfd85.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# # Initialize the LLM
# You will now initialize the LLM by creating an instance of WatsonxLLM, a class in langchain_ibm. WatsonxLLM can use several underlying foundational models. In this particular example, you will use Mixtral 8x7B, although you could have used other models, such as Llama 3.1 405B. For a list of foundational models available at watsonx.ai, refer to this.
#
# To initialize the LLM, paste the following into qabot.py. Note that you are initializing the model with a temperature of 0.5, and allowing for the generation of a maximum of 256 tokens:

# %%
## LLM
def get_llm():
    model_id = 'mistralai/mixtral-8x7b-instruct-v01'
    parameters = {
        GenParams.MAX_NEW_TOKENS: 256,
        GenParams.TEMPERATURE: 0.5,
    }
    project_id = "skills-network"
    watsonx_llm = WatsonxLLM(
        model_id=model_id,
        url="https://us-south.ml.cloud.ibm.com",
        project_id=project_id,
        params=parameters,
    )
    return watsonx_llm

# %% [markdown]
# # Define the PDF document loader
# Next, you will define the PDF document loader. You will use the PyPDFLoader class from the langchain_community library to load PDF documents. The syntax is quite straightforward. First, you create the PDF loader as an instance of PyPDFLoader. Then, you load the document and return the loaded document. To incorporate the PDF loader in your bot, add the following to qabot.py:

# %%
## Document loader
def document_loader(file):
    loader = PyPDFLoader(file.name)
    loaded_document = loader.load()
    return loaded_document

# %% [markdown]
# # Define the text splitter
# The PDF document loader loads the document but does not split it into chunks when using the .load() method. Consequently, you must define a document splitter that will split the text into chunks. Add the following code to qabot.py to define such a text splitter. Note that, in this example, you are defining a RecursiveCharacterTextSplitter with a chunk size of 1000, although other splitters or parameter values are possible:

# %%
## Text splitter
def text_splitter(data):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=1000,
        chunk_overlap=50,
        length_function=len,
    )
    chunks = text_splitter.split_documents(data)
    return chunks

# %% [markdown]
# # Define the vector store
# Now that you have a way to load the PDF into text and split that text into chunks, you must define a way to embed and store those chunks in a vector database. Add the following code to qabot.py to define a function that embeds the chunks using a yet to be defined embedding model and stores the embeddings in a ChromaDB vector store:

# %%
## Vector db
def vector_database(chunks):
    embedding_model = watsonx_embedding()
    vectordb = Chroma.from_documents(chunks, embedding_model)
    return vectordb

# %% [markdown]
# # Define the embedding model
# The above vector_database() function assumes the existence of a watsonx_embedding() function that loads an instance of an embedding model. This embedding model is needed to convert chunks of text into vector representations. The following code defines a watsonx_embedding() function that returns an instance of WatsonxEmbeddings, a class from langchain_ibm that generates embeddings. In this particular case, the embeddings are generated using IBM's Slate 125M English embeddings model. Paste this code into the qabot.py file:

# %%
## Embedding model
def watsonx_embedding():
    embed_params = {
        EmbedTextParamsMetaNames.TRUNCATE_INPUT_TOKENS: 3,
        EmbedTextParamsMetaNames.RETURN_OPTIONS: {"input_text": True},
    }
    watsonx_embedding = WatsonxEmbeddings(
        model_id="ibm/slate-125m-english-rtrvr",
        url="https://us-south.ml.cloud.ibm.com",
        project_id="skills-network",
        params=embed_params,
    )
    return watsonx_embedding

# %% [markdown]
# # Define the retriever
# Now that your vector store is defined, you must define a retriever that retrieves chunks of the document from it. In this particular case, you will define a vector store-based retriever that retrieves information using a simple similarity search. To do so, add the following lines to qabot.py:

# %%
## Retriever
def retriever(file):
    splits = document_loader(file)
    chunks = text_splitter(splits)
    vectordb = vector_database(chunks)
    retriever = vectordb.as_retriever()
    return retriever

# %% [markdown]
# # Define a question-answering chain
# Finally, it is time to define a question-answering chain! In this particular example, you will use RetrievalQA from langchain, a chain that performs natural-language question-answering over a data source using retrieval-augmented generation (RAG). Add the following code to qabot.py to define a question-answering chain:

# %%
## QA Chain
def retriever_qa(file, query):
    llm = get_llm()
    retriever_obj = retriever(file)
    qa = RetrievalQA.from_chain_type(llm=llm,
                                    chain_type="stuff",
                                    retriever=retriever_obj,
                                    return_source_documents=False)
    response = qa.invoke(query)
    return response['result']

# %% [markdown]
# # Set up the Gradio interface
# Given that you have created the core functionality of the bot, the final item to define is the Gradio interface. Your Gradio interface should include:
#
# A file upload functionality (provided by the File class in Gradio)
# An input textbox where the question can be asked (provided by the Textbox class in Gradio)
# An output textbox where the question can be answered (provided by the Textbox class in Gradio)
# Add the following code to qabot.py to add the Gradio interface:

# %%
# Create Gradio interface
rag_application = gr.Interface(
    fn=retriever_qa,
    # allow_flagging="never",
    inputs=[
        gr.File(label="Upload PDF File", file_count="single", file_types=['.pdf'], type="filepath"),  # Drag and drop file upload
        gr.Textbox(label="Input Query", lines=2, placeholder="Type your question here...")
    ],
    outputs=gr.Textbox(label="Output"),
    title="RAG Chatbot",
    description="Upload a PDF document and ask any question. The chatbot will try to answer using the provided document."
)

# %% [markdown]
# # Add code to launch the application

# %%
# Launch the app with a public link
rag_application.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://a0b0918a2573513ee3.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://a0b0918a2573513ee3.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
